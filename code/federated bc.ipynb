# %%
import pandas as pd
import numpy as np
import networkx as nx
import random
from sklearn.metrics import precision_score, recall_score, f1_score
from web3 import Web3
import json

# %%
# === Preprocess Last.fm Dataset ===
def preprocess_lastfm(path):
    df = pd.read_csv(path)
    df.rename(columns={"Username": "user_id", "Artist": "item_id"}, inplace=True)
    interaction_counts = df.groupby(['user_id', 'item_id']).size().reset_index(name='count')

    def count_to_rating(count):
        return min(5, max(1, int(np.log1p(count) / np.log(10) * 5)))

    interaction_counts['rating'] = interaction_counts['count'].apply(count_to_rating)
    interaction_counts['timestamp'] = pd.Timestamp.now().timestamp()
    return interaction_counts

# Load dataset
df = preprocess_lastfm(r"C:\Users\anuna\Downloads\Last.fm_data.csv\Last.fm_data.csv")

# %%
# === Federated Setup ===
NUM_CLIENTS = 5
TOP_K = 5
users = df['user_id'].unique()
random.shuffle(users)
client_user_splits = np.array_split(users, NUM_CLIENTS)
client_datasets = [df[df['user_id'].isin(split)] for split in client_user_splits]

# %%
# === Graph Recommender ===
def build_graph(df):
    G = nx.Graph()
    for _, group in df.groupby("user_id"):
        items = group['item_id'].tolist()
        for i in range(len(items)):
            for j in range(i + 1, len(items)):
                G.add_edge(items[i], items[j], weight=G.get_edge_data(items[i], items[j], {}).get('weight', 0) + 1)
    return G

def recommend(graph, user_df, top_k=TOP_K):
    user_items = set(user_df['item_id'])
    scores = {}
    for item in user_items:
        for neighbor in graph.neighbors(item):
            if neighbor not in user_items:
                scores[neighbor] = scores.get(neighbor, 0) + graph[item][neighbor]['weight']
    return sorted(scores, key=scores.get, reverse=True)[:top_k]

# %%
# === Evaluation ===
def evaluate(client_df, train_graph, top_k=TOP_K):
    users = client_df['user_id'].unique()
    precisions, recalls, f1s, hits = [], [], [], []
    for user in users:
        user_df = client_df[client_df['user_id'] == user]
        items = user_df['item_id'].tolist()
        if len(items) < 2:
            continue
        random.shuffle(items)
        split = int(len(items) * 0.5)
        train_items = items[:split]
        test_items = items[split:]

        user_partial_df = pd.DataFrame({'user_id': [user]*len(train_items), 'item_id': train_items})
        recs = recommend(train_graph, user_partial_df, top_k)

        y_true = [1 if item in test_items else 0 for item in recs]
        y_pred = [1]*len(y_true)

        if sum(y_true) > 0:
            precisions.append(precision_score(y_true, y_pred))
            recalls.append(recall_score(y_true, y_pred))
            f1s.append(f1_score(y_true, y_pred))
            hits.append(1 if any(y_true) else 0)

    return {
        'precision': np.mean(precisions) if precisions else 0,
        'recall': np.mean(recalls) if recalls else 0,
        'f1': np.mean(f1s) if f1s else 0,
        'hit_rate': np.mean(hits) if hits else 0
    }

# %%
# === Blockchain Integration ===
w3 = Web3(Web3.HTTPProvider("http://127.0.0.1:8545"))
admin = w3.eth.accounts[0]
clients = w3.eth.accounts[1:6]

# %%
abi = [
    {
        "inputs": [],
        "stateMutability": "nonpayable",
        "type": "constructor"
    },
    {
        "inputs": [],
        "name": "admin",
        "outputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "name": "balanceOf",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "name": "clients",
        "outputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "decimals",
        "outputs": [
            {
                "internalType": "uint8",
                "name": "",
                "type": "uint8"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "distributeRewards",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            }
        ],
        "name": "getClientBalance",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            }
        ],
        "name": "getClientScore",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "name",
        "outputs": [
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "name": "performanceScores",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            }
        ],
        "name": "registerClient",
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            },
            {
                "internalType": "uint256",
                "name": "f1Score",
                "type": "uint256"
            }
        ],
        "name": "submitPerformance",  # Renamed to avoid selector collision
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "symbol",
        "outputs": [
            {
                "internalType": "string",
                "name": "",
                "type": "string"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "totalSupply",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [],
        "name": "getClients",
        "outputs": [
            {
                "internalType": "address[]",
                "name": "",
                "type": "address[]"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            }
        ],
        "name": "getPerformance",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            }
        ],
        "name": "isClientRegistered",
        "outputs": [
            {
                "internalType": "bool",
                "name": "",
                "type": "bool"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "name": "performance",
        "outputs": [
            {
                "internalType": "uint256",
                "name": "",
                "type": "uint256"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "client",
                "type": "address"
            },
            {
                "internalType": "uint256",
                "name": "f1_scaled",
                "type": "uint256"
            }
        ],
        "name": "submitPerformance_v2",  # Renamed to avoid selector collision
        "outputs": [],
        "stateMutability": "nonpayable",
        "type": "function"
    },
    {
        "inputs": [
            {
                "internalType": "address",
                "name": "",
                "type": "address"
            }
        ],
        "name": "registered",
        "outputs": [
            {
                "internalType": "bool",
                "name": "",
                "type": "bool"
            }
        ],
        "stateMutability": "view",
        "type": "function"
    }
]

# %%
contract_address = Web3.to_checksum_address("0xe7f1725E7734CE288F8367e1Bb143E90bb3F0512")
contract = w3.eth.contract(address=contract_address, abi=abi)

# %%
def sign_and_send(tx_func, sender):
    tx = tx_func.build_transaction({
        'from': sender,
        'nonce': w3.eth.get_transaction_count(sender),
        'gas': 3000000,
        'gasPrice': w3.to_wei('1', 'gwei')
    })
    tx_hash = w3.eth.send_transaction(tx)
    return w3.eth.wait_for_transaction_receipt(tx_hash)

# %%
for client in clients:
    sign_and_send(contract.functions.registerClient(client), admin)

# %%
# Build global graph and evaluate clients
global_graph = build_graph(df)
all_metrics = []
for i, client_df in enumerate(client_datasets):
    metrics = evaluate(client_df, global_graph)
    all_metrics.append(metrics)
    f1_scaled = int(metrics['f1'] * 100)
    sign_and_send(contract.functions.submitPerformance(clients[i], f1_scaled), admin)

# %%
# Distribute rewards
sign_and_send(contract.functions.distributeRewards(), admin)
# Out:
# AttributeDict({'cumulativeGasUsed': 21160,
#  'logsBloom': HexBytes('...'),
#  'logs': [],
#  'status': 1,
#  'type': 0,
#  'transactionHash': HexBytes('0x14f3dc9b0b4972d5b8ca4db312ec154b7427b7f3682a8eda07f21def9b913de8'),
#  'transactionIndex': 0,
#  'from': '0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266',
#  'to': '0xe7f1725E7734CE288F8367e1Bb143E90bb3F0512',
#  'contractAddress': None,
#  'gasUsed': 21160,
#  'effectiveGasPrice': 1000000000,
#  'blockHash': HexBytes('0x0029891186eade368073f16ffce59364f4d161a3666ce1dfa0b69a71c28a79d2'),
#  'blockNumber': 1})

# %%
# Final token balances
print("\n=== Final Token Balances ===")
for client in clients:
    balance = contract.functions.getClientBalance(client).call()
    print(f"{client}: {balance / 1e18:.4f} FRT")
# Out:
# === Final Token Balances ===
# ---------------------------------------------------------------------------
# ContractLogicError                        Traceback (most recent call last)
# Cell In[24], line 4
#       2 print("\n=== Final Token Balances ===")
#       3 for client in clients:
# ----> 4     balance = contract.functions.getClientBalance(client).call()
#       5     print(f"{client}: {balance / 1e18:.4f} FRT")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\contract\contract.py:291, in ContractFunction.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     287 block_id = parse_block_identifier(self.w3, block_identifier)
#     289 abi_element_identifier = abi_to_signature(self.abi)
# --> 291 return call_contract_function(
#     292     self.w3,
#     293     self.address,
#     294     self._return_data_normalizers,
#     295     abi_element_identifier,
#     296     call_transaction,
#     297     block_id,
#     298     self.contract_abi,
#     299     self.abi,
#     300     state_override,
#     301     ccip_read_enabled,
#     302     self.decode_tuples,
#     303     *self.args or (),
#     304     **self.kwargs or {},
#     305 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\contract\utils.py:154, in call_contract_function(w3, address, normalizers, abi_element_identifier, transaction, block_id, contract_abi, abi_callable, state_override, ccip_read_enabled, decode_tuples, *args, **kwargs)
#     139 """
#     140 Helper function for interacting with a contract function using the
#     141 `eth_call` API.
#     142 """
#     143 call_transaction = prepare_transaction(
#     144     address,
#     145     w3,
#    (...)    151     fn_kwargs=kwargs,
#     152 )
# --> 154 return_data = w3.eth.call(
#     155     call_transaction,
#     156     block_identifier=block_id,
#     157     state_override=state_override,
#     158     ccip_read_enabled=ccip_read_enabled,
#     159 )
#     161 if abi_callable is None:
#     162     abi_callable = cast(
#     163         ABIFunction,
#     164         get_abi_element(
#    (...)    170         ),
#     171     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\eth\eth.py:246, in Eth.call(self, transaction, block_identifier, state_override, ccip_read_enabled)
#     236 ccip_read_enabled_on_provider = self.w3.provider.global_ccip_read_enabled
#     237 if (
#     238     # default conditions:
#     239     ccip_read_enabled_on_provider
#    (...)    244     and ccip_read_enabled is True
#     245 ):
# --> 246     return self._durin_call(transaction, block_identifier, state_override)
#     248 return self._call(transaction, block_identifier, state_override)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\eth\eth.py:265, in Eth._durin_call(self, transaction, block_identifier, state_override)
#     263 for _ in range(max_redirects):
#     264     try:
# --> 265         return self._call(transaction, block_identifier, state_override)
#     266     except OffchainLookup as offchain_lookup:
#     267         durin_calldata = handle_offchain_lookup(
#     268             offchain_lookup.payload,
#     269             transaction,
#     270         )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\module.py:112, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     105     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     107 (
#     108     result_formatters,
#     109     error_formatters,
#     110     null_result_formatters,
#     111 ) = response_formatters
# --> 112 result = w3.manager.request_blocking(
#     113     method_str, params, error_formatters, null_result_formatters
#     114 )
#     115 return apply_result_formatters(result_formatters, result)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\manager.py:232, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     228 """
#     229 Make a synchronous request using the provider
#     230 """
#     231 response = self._make_request(method, params)
# --> 232 return self.formatted_response(
#     233     response, params, error_formatters, null_result_formatters
#     234 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\manager.py:198, in RequestManager.formatted_response(self, response, params, error_formatters, null_result_formatters)
#     184 def formatted_response(
#     185     self,
#     186     response: RPCResponse,
#    (...)    189     null_result_formatters: Optional[Callable[..., Any]] = None,
#     190 ) -> Any:
#     191     is_subscription_response = (
#     192         response.get("method") == "eth_subscription"
#     193         and response.get("params") is not None
#     194         and response["params"].get("subscription") is not None
#     195         and response["params"].get("result") is not None
#     196     )
# --> 198     validate_rpc_response_and_raise_if_error(
#     199         response,
#     200         error_formatters,
#     201         is_subscription_response=is_subscription_response,
#     202         logger=self.logger,
#     203         params=params,
#     204     )
#     206     # format results
#     207     if "result" in response:
#     208         # Null values for result should apply null_result_formatters
#     209         # Skip when result not present in the response (fallback to False)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\_utils\validation.py:397, in validate_rpc_response_and_raise_if_error(response, error_formatters, is_subscription_response, logger, params)
#     393 if web3_rpc_error is None:
#     394     # if no condition was met above, raise a more generic `Web3RPCError`
#     395     web3_rpc_error = Web3RPCError(repr(error), rpc_response=response)
# --> 397 response = apply_error_formatters(error_formatters, response)
#     398 if logger is not None:
#     399     logger.debug(f"RPC error response: {response}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\_utils\formatters.py:146, in apply_error_formatters(error_formatters, response)
#     141 def apply_error_formatters(
#     142     error_formatters: Callable[..., Any],
#     143     response: RPCResponse,
#     144 ) -> RPCResponse:
#     145     if error_formatters:
# --> 146         formatted_resp = pipe(response, error_formatters)
#     147         return formatted_resp
#     148     else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cytoolz\functoolz.pyx:685, in cytoolz.functoolz.pipe()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\cytoolz\functoolz.pyx:660, in cytoolz.functoolz.c_pipe()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\_utils\error_formatters_utils.py:158, in raise_contract_logic_error_on_revert(response)
#     156         raise ContractLogicError("execution reverted", data=data)
#     157 elif isinstance(data, dict) and message_present:
# --> 158     raise ContractLogicError(f"execution reverted: {message}", data=data)
#     159 elif isinstance(data, str):
#     160     _raise_contract_error(data)
#
# ContractLogicError: ("execution reverted: Error: Transaction reverted: function selector was not recognized and there's no fallback function", {'message': "Error: Transaction reverted: function selector was not recognized and there's no fallback function", 'data': '0x'})

# %%
print(w3.is_connected())
print(w3.eth.get_block('latest'))
# Out:
# True
# AttributeDict({'hash': HexBytes('0x6d0819560e4149246b10644e99dba4e05b4d4cc30e14a6868b75d650193551fe'), 'parentHash': HexBytes('0xbfbebc4aae7ff70697710b2f4c41d69567729689b6ad593197c48abe7ed56dc3'), 'sha3Uncles': HexBytes('0x1dcc4de8dec75d7aab85b567b6ccd41ad312451b948a7413f0a142fd40d49347'), 'stateRoot': HexBytes('0x4ba55a05b098f0bcbe0abd3f97c8a5adbb0107f449f1cd31bb8b410fa141ebdc'), 'transactionsRoot': HexBytes('0xcb810436f693cb10e955dcc7404f25e8540b8506db543bc16e16be9da20de45d'), 'receiptsRoot': HexBytes('0xaa7bc2a3b0acec28282c0bad2b7984f3581e3cdfbe418c687f2ed8d3d1f65451'), 'number': 28, 'gasUsed': 21160, 'gasLimit': 30000000, 'extraData': HexBytes('0x'), 'logsBloom': HexBytes('...'), 'timestamp': 1746864201, 'difficulty': 0, 'totalDifficulty': 0, 'uncles': [], 'transactions': [HexBytes('0x166e75637b9625ae81f489a384502e1a22d50dd18f53ca9468676c318c2c198b')], 'size': 727, 'mixHash': HexBytes('0xe8087465d26dce51c90cf9a35dee7ecdbfd754a3dc5a49a74d05c80a0876aa6e'), 'nonce': HexBytes('0x0000000000000000'), 'baseFeePerGas': 23943165, 'miner': '0xC014BA5EC014ba5ec014Ba5EC014ba5Ec014bA5E', 'withdrawals': [], 'withdrawalsRoot': HexBytes('0x56e81f171bcc55a6ff8345e692c0f86e5b48e01b996cadc001622fb5e363b421'), 'blobGasUsed': 0, 'excessBlobGas': 0, 'parentBeaconBlockRoot': HexBytes('0xba4b588cffb9d35e553e5e131bda0165b2a9b9478977be1add3eec75e3b74f25'), 'requestsHash': HexBytes('0xe3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855')})

# %%
print(contract.functions.getClients().call())
# Out:
# ---------------------------------------------------------------------------
# ABIFunctionNotFound                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(contract.functions.getClients().call())
#
# File ~\AppData\Roaming\Python\Python313\site-packages\web3\contract\base_contract.py:965, in BaseContractFunctions.__getattr__(self, function_name)
#     957     raise NoABIFunctionsFound(
#     958         "The abi for this contract contains no function definitions. ",
#     959         "Are you sure you provided the correct contract abi?",
#     960     )
#     961 elif get_name_from_abi_element_identifier(function_name) not in [
#     962     get_name_from_abi_element_identifier(function["name"])
#     963     for function in self._functions
#     964 ]:
# --> 965     raise ABIFunctionNotFound(
#     966         f"The function '{function_name}' was not found in this ",
#     967         "contract's abi.",
#     968     )
#     970 if "(" not in function_name:
#     971     function_name = _get_any_abi_signature_with_name(
#     972         function_name, self._functions
#     973     )
#
# ABIFunctionNotFound: ("The function 'getClients' was not found in this ", "contract's abi.")

# %%
try:
    balance = contract.functions.getClientBalance(client).call()
    print(f"{client}: {balance}")
except Exception as e:
    print(f"Error: {str(e)}")
# Out:
# Error: ("execution reverted: Error: Transaction reverted: function selector was not recognized and there's no fallback function", {'message': "Error: Transaction reverted: function selector was not recognized and there's no fallback function", 'data': '0x'})
